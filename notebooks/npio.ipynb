# %%
""" Used when checked out from Git """
import sys
import os
def add_local():
    d = os.getcwd()
    assert d[-9:] == "notebooks", "This code assume that the notebook is run out of 'notebooks'. Remove this code if not needed"
    sys.path.insert( 0, d[:-10] )
    print(f"Added '{d[:-10]}' to the import path")
add_local()
# Out:
# Added 'C:\Users\hans\OneDrive\Python3\packages\cdxcore' to the import path

# %%
import importlib as imp
import cdxcore.npio as _
imp.reload(_)

from cdxcore.npio import tofile, read_shape_and_dtype, readinto, fromfile
from cdxcore.subdir import SubDir

import numpy as np

import pickle as pickle
import tempfile as tempfile

def func():
    print(sub.path)

sub = SubDir("?/test;*.bin")    
print(sub)


np.random.seed(1231)
array = (np.random.normal(size=(1000,3))*100.).astype(np.int32)
file  = sub("test", create_directory=True).full_file_name("test")

tofile( file, array )

test = fromfile( file )
assert np.all( test==array )
# Out:
# C:/Users/hans/AppData/Local/Temp/tmp_0inqz7y/test/;*.bin

# %%
sub = SubDir("?/test;*.bin")    
print(sub)


np.random.seed(1231)
array = (np.random.normal(size=(1000,3))*100.).astype(np.int32)
file  = sub("test", create_directory=True).full_file_name("test")

tofile( file, array )

out = np.empty( array.shape )
test = fromfile( file )
assert np.all( test==array )
# Out:
# C:/Users/hans/AppData/Local/Temp/tmp6wd1t7jd/test/;*.bin

# %%
sub = SubDir("?/test;*.bin")    
print(sub)


np.random.seed(1231)
array = (np.random.normal(size=(1000,3))*100.).astype(np.int32)
file  = sub("test", create_directory=True).full_file_name("test")

tofile( file, array )

out = np.empty( array.shape, dtype=np.int8 )
test = fromfile( file )
assert np.all( test==array )
# Out:
# C:/Users/hans/AppData/Local/Temp/tmpsclr0brr/test/;*.bin

# %%
import importlib as imp
import cdxcore.npio as _
imp.reload(_)

from cdxcore.npio import tofile, read_shape_and_dtype, readinto, fromfile
from cdxcore.subdir import SubDir

import numpy as np

import pickle as pickle
import tempfile as tempfile


sub = SubDir("?/test;*.bin")    
print(sub)


np.random.seed(1231)
array = (np.random.normal(size=(1000,3))*100.).astype(np.int32)
file  = sub("test", create_directory=True).full_file_name("test")

tofile( file, array )

test = fromfile( file, validate_dtype=np.float32 )
assert np.all( test==array )
# Out:
# C:/Users/hans/AppData/Local/Temp/tmp08q_2i14/test/;*.bin
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 24
#      20 file  = sub("test", create_directory=True).full_file_name("test")
#      22 tofile( file, array )
# ---> 24 test = fromfile( file, validate_dtype=np.float32 )
#      25 assert np.all( test==array )
#
# File ~\OneDrive\Python3\packages\cdxcore\cdxcore\npio.py:394, in fromfile(file, validate_dtype, validate_shape, read_only, buffering)
#     355 def fromfile( file, *, validate_dtype = None, validate_shape = None, read_only : bool = False, buffering : int = -1  ) -> np.ndarray:
#     356     """
#     357     Read array from disk into a new :class:`numpy.ndarray`.
#     358
#    (...)
#     392             or if it does not match the geometry of ``target`` if provided as a numpy array.
#     393     """
# --> 394     return readfromfile( file,
#     395                          target=lambda shape, dtype : np.empty( shape=shape, dtype=dtype ),
#     396                          read_only = read_only,
#     397                          validate_dtype=validate_dtype,
#     398                          validate_shape=validate_shape,
#     399                          buffering=buffering )
#
# File ~\OneDrive\Python3\packages\cdxcore\cdxcore\npio.py:251, in readfromfile(file, target, read_only, buffering, validate_dtype, validate_shape)
#     249 if isinstance(file, str):
#     250     with open( file, "rb", buffering=buffering ) as f:
# --> 251         return readfromfile( f, target,
#     252                              read_only=read_only,
#     253                              buffering=buffering,
#     254                              validate_dtype=validate_dtype,
#     255                              validate_shape=validate_shape )
#     256 f = file
#     257 del file
#
# File ~\OneDrive\Python3\packages\cdxcore\cdxcore\npio.py:263, in readfromfile(***failed resolving arguments***)
#     260 shape, dtype = _readheader(f)
#     262 if not validate_dtype is None and validate_dtype != dtype:
# --> 263     raise IOError(f"Failed to read {f.name}: found type {dtype} expected {validate_dtype}.")
#     264 if not validate_shape is None and validate_shape != shape:
#     265     raise IOError(f"Failed to read {f.name}: found type {shape} expected {validate_shape}.")
#
# OSError: Failed to read C:/Users/hans/AppData/Local/Temp/tmp08q_2i14/test/test/test.bin: found type int32 expected <class 'numpy.float32'>.
