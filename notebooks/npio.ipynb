# %%
""" Used when checked out from Git """
import sys
import os
def add_local():
    d = os.getcwd()
    assert d[-9:] == "notebooks", "This code assume that the notebook is run out of 'notebooks'. Remove this code if not needed"
    sys.path.insert( 0, d[:-10] )
    print(f"Added '{d[:-10]}' to the import path")
add_local()
# Out:
# Added 'C:\Users\hans\OneDrive\Python3\packages\cdxcore' to the import path

# %%
import importlib as imp
import cdxcore.npio as _
imp.reload(_)

from cdxcore.npio import to_file, read_shape_and_dtype, read_into, from_file
from cdxcore.subdir import SubDir

import numpy as np

import pickle as pickle
import tempfile as tempfile

def func():
    print(sub.path)

sub = SubDir("?/test;*.bin")    
print(sub)


np.random.seed(1231)
array = (np.random.normal(size=(1000,3))*100.).astype(np.int32)
file  = sub("test", create_directory=True).full_file_name("test")

to_file( file, array )

test = from_file( file )
assert np.all( test==array )
print("fine")
# Out:
# C:/Users/hans/AppData/Local/Temp/tmpwu_1phmq/test/;*.bin

# %%
sub = SubDir("?/test;*.bin")    
print(sub)


np.random.seed(1231)
array = (np.random.normal(size=(1000,3))*100.).astype(np.int32)
file  = sub("test", create_directory=True).full_file_name("test")

to_file( file, array )

out = np.empty( array.shape )
test = from_file( file )
assert np.all( test==array )
print("fine")
# Out:
# C:/Users/hans/AppData/Local/Temp/tmpg3nzhcbf/test/;*.bin
# fine

# %%
import importlib as imp
import cdxcore.npio as _
imp.reload(_)

from cdxcore.npio import to_file, read_shape_and_dtype, read_into, from_file
from cdxcore.subdir import SubDir

import numpy as np

import pickle as pickle
import tempfile as tempfile
import gc as gc

sub = SubDir("?;*.bin", delete_everything_upon_exit=True )
print(sub)
del sub
gc.collect()

sub = SubDir("?;*.bin", delete_everything_upon_exit=True )
print(sub)


np.random.seed(1231)
array = (np.random.normal(size=(1000,3))*100.).astype(np.int32)
file  = sub("test", create_directory=True).full_file_name("test")

to_file( file, array )

try:
    test = from_file( file, validate_dtype=np.float32 )
except OSError as e:
    print(e)

test = from_file( file, validate_dtype=np.int32 )

assert np.all( test==array )
print("fine")
# Out:
# C:/Users/hans/AppData/Local/Temp/tmp5xorzzjq/;*.bin
# C:/Users/hans/AppData/Local/Temp/tmpghds9b0p/;*.bin
# Failed to read C:/Users/hans/AppData/Local/Temp/tmpghds9b0p/test/test.bin: found type <class 'numpy.int32'> expected <class 'numpy.float32'>.
# fine

# %%
array = np.zeros((4,4), dtype=np.int8)
for i in range(array.shape[-1]):
    array[:,i] = i

x = np.zeros((3,3))[:,1]
print(x.data.contiguous)
y = x.reshape(len(x))
print(y.data.contiguous)
yy = np.ascontiguousarray(y.data[:2])
print(yy.dtype)
z = memoryview(yy).cast('B')

print( len(z), len(yy), len(yy.data) )
# Out:
# False
# False
# float64
# 16 2 2
