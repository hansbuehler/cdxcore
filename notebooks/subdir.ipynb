# %%
""" Used when checked out from Git """
import sys
import os

# uncomment if you want to use local "cdxcore" in /packages/cdxcore
def add_local():
    import sys
    import os
    d = os.getcwd().lower().replace("\\","/")
    test = ['python3','python']
    nd = None
    for t in test:
        i = d.find(t)
        if i!=-1:
            nd = d[:i+len(t)] + "/packages/cdxcore"
            break
        
    assert not nd is None, f"This code assume that {__file__} is run out of 'python'. Found {d}. Remove this code if not needed"
    if sys.path[0] != nd:
        sys.path.insert( 0, nd )
        print(f"Added '{nd}' to the import path")
add_local()

import importlib as imp
import cdxcore.subdir as _
imp.reload(_)
# Out:
# Added 'C:\Users\hans\OneDrive\Python3\packages\cdxcore' to the import path

# %%
from cdxcore.subdir import SubDir, CacheController, Context

ctrl    = CacheController( debug_verbose=Context("all") )
cache   = SubDir("!/.cache", cache_controller=ctrl )
cache.delete_all_content()

@cache.cache("0.1")
def f(x,y):
    return x*y

_ = f(1,2)    # function gets computed and the result cached
_ = f(1,2)    # restore result from cache
_ = f(2,2)    # different parameters: compute and store result
# Out:
# 00: cache(f@__main__): function registered for caching into 'C:/Users/hans/AppData/Local/Temp/.cache/'.
# 00: cache(f@__main__): called 'f@__main__' version 'version 0.1' and wrote result into 'C:/Users/hans/AppData/Local/Temp/.cache/f@__main__ 2ad4e1bd.pck'.
# 00: cache(f@__main__): read 'f@__main__' version 'version 0.1' from cache 'C:/Users/hans/AppData/Local/Temp/.cache/f@__main__ 2ad4e1bd.pck'.
# 00: cache(f@__main__): called 'f@__main__' version 'version 0.1' and wrote result into 'C:/Users/hans/AppData/Local/Temp/.cache/f@__main__ 72020ab6.pck'.

# %%
from cdxcore.subdir import SubDir, CacheController, Context
ctrl    = CacheController( debug_verbose=Context("all") )
cache   = SubDir("!/.cache", cache_controller=ctrl )
cache.delete_all_content()   # <- delete previous cached files, for thise example only

@cache.cache("0.1")                     # <- no ID 
def f1(x,y):
    return x*y

@cache.cache("0.1", label="f2({x},{y})") # <- label uses a string to be passed to str.format()
def f2(x,y):
    return x*y

@cache.cache("0.1", label=lambda x,y,**_: f"h({x},{y})", exclude_args='debug') 
def h(x,y,debug=False):
    if debug:
        print(f"h(x={x},y={y})")  
    return x*y
f1(1,1)
f2(1,1)
h(1,1)
# Out:
# 00: cache(f1@__main__): function registered for caching into 'C:/Users/hans/AppData/Local/Temp/.cache/'.
# 00: cache(f2@__main__): function registered for caching into 'C:/Users/hans/AppData/Local/Temp/.cache/'.
# 00: cache(h@__main__): function registered for caching into 'C:/Users/hans/AppData/Local/Temp/.cache/'.
# 00: cache(f1@__main__): called 'f1@__main__' version 'version 0.1' and wrote result into 'C:/Users/hans/AppData/Local/Temp/.cache/f1@__main__ 993b6482.pck'.
# 00: cache(f2@__main__): called 'f2(1,1)' version 'version 0.1' and wrote result into 'C:/Users/hans/AppData/Local/Temp/.cache/f2(1,1) d8df569a.pck'.
# 00: cache(h@__main__): called 'h(1,1)' version 'version 0.1' and wrote result into 'C:/Users/hans/AppData/Local/Temp/.cache/h(1,1) 2e8829d8.pck'.
# 1

# %%
@cache.cache("0.1", uid=lambda x,y,**_: f"h2({x},{y})", exclude_args='debug') 
def h2(x,y,debug=False):
    if debug:
        print(f"h(x={x},y={y})")  
    return x*y
h2(1,1)

@cache.cache("0.1", uid=lambda x,y,**_: f"h2({x},{y})_______________________________________________________________________", exclude_args='debug') 
def h2(x,y,debug=False):
    if debug:
        print(f"h(x={x},y={y})")  
    return x*y
h2(1,1)
# Out:
# 00: cache(h2@__main__): function registered for caching into 'C:/Users/hans/AppData/Local/Temp/.cache/'.
# 00: cache(h2@__main__): called 'h2(1,1)' version 'version 0.1' and wrote result into 'C:/Users/hans/AppData/Local/Temp/.cache/h2(1,1).pck'.
# 00: cache(h2@__main__): function registered for caching into 'C:/Users/hans/AppData/Local/Temp/.cache/'.
# 00: cache(h2@__main__): called 'h2(1,1)_______________________________________________________________________' version 'version 0.1' and wrote result into 'C:/Users/hans/AppData/Local/Temp/.cache/h2(1,1)________________________________ 46a70d67.pck'.
# 1

# %%
"""
Generate filename issue
"""

@cache.cache("0.1", uid=lambda x,y,**_: f"i/({x},{y})", exclude_args='debug') 
def i(x,y,debug=False):
    if debug:
        print(f"h(x={x},y={y})")  
    return x*y
try:
    i(1,2)
except ValueError as e:
    print(e)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 """
#       2 Generate filename issue
#       3 """
# ----> 5 @cache.cache("0.1", uid=lambda x,y,**_: f"i/({x},{y})", exclude_args='debug')
#       6 def i(x,y,debug=False):
#       7     if debug:
#       8         print(f"h(x={x},y={y})")
#
# NameError: name 'cache' is not defined

# %%
# uncomment if you want to use local "cdxcore" in /packages/cdxcore
def add_local():
    import sys
    import os
    d = os.getcwd().lower().replace("\\","/")
    test = ['python3','python']
    nd = None
    for t in test:
        i = d.find(t)
        if i!=-1:
            nd = d[:i+len(t)] + "/packages/cdxcore"
            break
        
    assert not nd is None, f"This code assume that {__file__} is run out of 'python'. Found {d}. Remove this code if not needed"
    if sys.path[0] != nd:
        sys.path.insert( 0, nd )
        print(f"Added '{nd}' to the import path")
add_local()

import importlib as imp
import cdxcore.uniquehash as _
imp.reload(_)
import cdxcore.subdir as _
imp.reload(_)

from cdxcore.subdir import SubDir, VersionedCacheRoot, Context,CacheController

cache_controller=CacheController()
root = SubDir("!/subdir_cache_test2", cache_controller=cache_controller)

print(id(cache_controller))

print( root.cache_controller.uniqueFileName("test") )
print( root.cache_controller.labelledFileName("test", **dict(x=1)),root.cache_controller.labelledFileName )

class C(object):
    def __init__(self):
        self.cc = root.cache_controller
    @property
    def label(self):
        return self.cc.labelledFileName

print( C().label("Test") )

class A(object):
    def __init__(self):
        self.x = 3
    @root.cache("0.1")
    def f(self, y):
        return self.x*y

a = A()
a.f(2)
print(a.f.cache_info.last_cached)
a.f(2)
print(a.f.cache_info.last_cached)
a.f(3)
print(a.f.cache_info.last_cached)
# Out:
# 137802831145120
# test
# test f6baa010 <function NamedUniqueHash.<locals>.named_unique_hash at 0x7d54b86b1260>
# Test 2c8e5b31
# XXX A.f@__main__ 3c707933
# **** False (<__main__.A object at 0x7d54b995bb00>, 2) {}
# False
# XXX A.f@__main__ 3c707933
# True
# XXX A.f@__main__ bfa047b6
# **** False (<__main__.A object at 0x7d54b995bb00>, 3) {}
# False

# %%
def h(x,y):
    return x*y

class A(object):
    def __init__(self):
        self.h = h

a = A()
a.h(1,2)
# Out:
# 2

# %%
# uncomment if you want to use local "cdxcore" in /packages/cdxcore
def add_local():
    import sys
    import os
    d = os.getcwd().lower().replace("\\","/")
    test = ['python3','python']
    nd = None
    for t in test:
        i = d.find(t)
        if i!=-1:
            nd = d[:i+len(t)] + "/packages/cdxcore"
            break
        
    assert not nd is None, f"This code assume that {__file__} is run out of 'python'. Found {d}. Remove this code if not needed"
    if sys.path[0] != nd:
        sys.path.insert( 0, nd )
        print(f"Added '{nd}' to the import path")
add_local()

import importlib as imp
import cdxcore.subdir as _
imp.reload(_)

from cdxcore.subdir import SubDir
cache = SubDir("?/temp")

@cache.cache("0.1", label=lambda new_func_name, func_name, x : f"{new_func_name}(): {func_name} {x}", name_of_func_name_arg="new_func_name")
def f( func_name, x ):
    pass
f("test",1)

@cache.cache("0.1", label=lambda func_name, x : f"{func_name} {x}")
def f( func_name, x ):
    pass
f("test",1)
# Out:
# Exception ignored in: <function SubDir.__del__ at 0x7d54b98ec9a0>
# Traceback (most recent call last):
#   File "/mnt/c/users/hans/onedrive/python3/packages/cdxcore/cdxcore/subdir.py", line 1034, in __del__
#     if self._tclean:
#        ^^^^^^^^^^^^
# AttributeError: 'SubDir' object has no attribute '_tclean'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 30
#      27 @cache.cache("0.1", label=lambda new_func_name, func_name, x : f"{new_func_name}(): {func_name} {x}", name_of_func_name_arg="new_func_name")
#      28 def f( func_name, x ):
#      29     pass
# ---> 30 f("test",1)
#      32 @cache.cache("0.1", label=lambda func_name, x : f"{func_name} {x}")
#      33 def f( func_name, x ):
#      34     pass
#
# File /mnt/c/users/hans/onedrive/python3/packages/cdxcore/cdxcore/subdir.py:4069, in CacheCallable._wrap.<locals>.execute(***failed resolving arguments***)
#    4067 tag = Tag()
#    4068 if not is_new:
# -> 4069     r = self._subdir.read( filename, tag, version=version_ )
#    4070 else:
#    4071     try:
#
# File /mnt/c/users/hans/onedrive/python3/packages/cdxcore/cdxcore/subdir.py:1708, in SubDir.read(self, file, default, raise_on_error, version, delete_wrong_version, ext, fmt)
#    1615 def read( self, file : str,
#    1616                 default = None,
#    1617                 raise_on_error : bool = False,
#    (...)   1622                 fmt : Format|None = None
#    1623                 ):
#    1624     """
#    1625     Read data from a file if the file exists, or return ``default``.
#    1626
#    (...)   1706
#    1707     """
# -> 1708     return self._read( file=file,
#    1709                        default=default,
#    1710                        raise_on_error=raise_on_error,
#    1711                        version=version,
#    1712                        ext=ext,
#    1713                        fmt=fmt,
#    1714                        delete_wrong_version=delete_wrong_version,
#    1715                        handle_version=SubDir.VER_NORMAL )
#
# File /mnt/c/users/hans/onedrive/python3/packages/cdxcore/cdxcore/subdir.py:1613, in SubDir._read(self, file, default, raise_on_error, version, ext, fmt, delete_wrong_version, handle_version)
#    1607     deleted = " (file was deleted)" if e is None else " (attempt to delete file failed: %s)" % e
#    1608     raise VersionError( f"Error reading '{full_file_name}' using {fmt}: found version '{test_version}' not '{version}'{deleted}",
#    1609                         version_found=test_version,
#    1610                         version_expected=version
#    1611                         )
# -> 1613 return self._read_reader( reader=reader, file=file, default=default, raise_on_error=raise_on_error, ext=ext )
#
# File /mnt/c/users/hans/onedrive/python3/packages/cdxcore/cdxcore/subdir.py:1387, in SubDir._read_reader(self, reader, file, default, raise_on_error, ext)
#    1385 # vector version
#    1386 if not isinstance(file,str):
# -> 1387     if not isinstance(file, Collection): raise ValueError(txtfmt( "'file' must be a string, or an interable object. Found type %s", type(file)))
#    1388     l = len(file)
#    1389     if default is None or isinstance(default,str) or not isinstance(default, Collection):
#
# ValueError: 'file' must be a string, or an interable object. Found type <class 'NoneType'>

# %%
from cdxcore.subdir import SubDir, version
cache   = SubDir("?/.cache")
cache.delete_all_content()   # for illustration

@version("0.1")
class A(object):
    def __init__(self, x):
        self.x = x

    @cache.cache("0.1")
    def f(self, y):
        return self.x*y

a = A(x=1)
_ = a.f(y=1)   # compute f and store result
_ = a.f(y=1)   # load result back from disk
a.x = 2
_ = a.f(y=1)   # 'a' changed: compute f and store result
b = A(x=2)
_ = b.f(y=1)   # same unique call ID as previous call -> restore result from disk
# Out:
# XXX A.f@__main__ 6511c0b6
# **** False (<__main__.A object at 0x7d54b9e54ce0>,) {'y': 1}
# XXX A.f@__main__ 6511c0b6
# XXX A.f@__main__ bba17801
# **** False (<__main__.A object at 0x7d54b9e54ce0>,) {'y': 1}
# XXX A.f@__main__ bba17801

# %%
# uncomment if you want to use local "cdxcore" in /packages/cdxcore
def add_local():
    import sys
    import os
    d = os.getcwd().lower().replace("\\","/")
    test = ['python3','python']
    nd = None
    for t in test:
        i = d.find(t)
        if i!=-1:
            nd = d[:i+len(t)] + "/packages/cdxcore"
            break
        
    assert not nd is None, f"This code assume that {__file__} is run out of 'python'. Found {d}. Remove this code if not needed"
    if sys.path[0] != nd:
        sys.path.insert( 0, nd )
        print(f"Added '{nd}' to the import path")
add_local()

import importlib as imp
import cdxcore.version as _
imp.reload(_)
import cdxcore.subdir as _
imp.reload(_)

from cdxcore.subdir import SubDir, version
cache   = SubDir("!/.cache")
cache.delete_all_content()   # for illustration

class A(object):
    def __init__(self,x):
        self.x = x
    def f(self,y):
        return self.x*y

a = A(x=1)
f = cache.cache("0.1", label=lambda y : f"a.f({y})")(a.f)  # <- decorate bound 'f'.
_ = f(y=2)
print(f.cache_info.last_cached, f.cache_info.filename)
_ = f(y=2)
print(f.cache_info.last_cached, f.cache_info.filename)
# Out:
# False a.f(2) b35e3e1e
# True a.f(2) b35e3e1e

# %%
A(1).f.__dict__['test']= 1
A(1).f.test
# Out:
# 1

# %%
import inspect
inspect.ismethod(A(1).f)
# Out:
# True

# %%
# uncomment if you want to use local "cdxcore" in /packages/cdxcore
def add_local():
    import sys
    import os
    d = os.getcwd().lower().replace("\\","/")
    test = ['python3','python']
    nd = None
    for t in test:
        i = d.find(t)
        if i!=-1:
            nd = d[:i+len(t)] + "/packages/cdxcore"
            break
        
    assert not nd is None, f"This code assume that {__file__} is run out of 'python'. Found {d}. Remove this code if not needed"
    if sys.path[0] != nd:
        sys.path.insert( 0, nd )
        print(f"Added '{nd}' to the import path")
add_local()

import importlib as imp
import cdxcore.version as _
imp.reload(_)
import cdxcore.subdir as _
imp.reload(_)

from cdxcore.subdir import SubDir

sub = SubDir("!/test")

@version("F1")
def F(x):
    return x

@sub.cache("G1")
def G(x):
    return x

@sub.cache("H", dependencies=[F,G])
def H(x):
    return G(x)*F(x)

h = H(2.)
print(H.version)
print(H.cache_info.version)
# Out:
# H { F: F1, G: G1 }
# H { F: F1, G: G1 }

# %%
import inspect

f = lambda x, y : f"{x}{y}"
list(inspect.signature(f).parameters)
# Out:
# ['x', 'y']

# %%
# uncomment if you want to use local "cdxcore" in /packages/cdxcore
def add_local():
    import sys
    import os
    d = os.getcwd().lower().replace("\\","/")
    test = ['python3','python']
    nd = None
    for t in test:
        i = d.find(t)
        if i!=-1:
            nd = d[:i+len(t)] + "/packages/cdxcore"
            break
        
    assert not nd is None, f"This code assume that {__file__} is run out of 'python'. Found {d}. Remove this code if not needed"
    if sys.path[0] != nd:
        sys.path.insert( 0, nd )
        print(f"Added '{nd}' to the import path")
add_local()

import importlib as imp
import cdxcore.version as _
imp.reload(_)
import cdxcore.subdir as _
imp.reload(_)

from cdxcore.subdir import SubDir

sub = SubDir("?/cache")

@sub.cache("0.1", label=lambda x : f"x={x}")
def f(x,y):
    return x*y
_ = f(1,2)
print(f.cache_info.label)

@sub.cache("0.1", label=lambda x, z : f"x={x}, z={x}")
def f(x,y):
    return x*y
_ = f(1,2)
print(f.cache_info.label)
# Out:
# x=1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 39
#      36 @sub.cache("0.1", label=lambda x, z : f"x={x}, z={x}")
#      37 def f(x,y):
#      38     return x*y
# ---> 39 _ = f(1,2)
#      40 print(f.cache_info.label)
#
# File /mnt/c/users/hans/onedrive/python3/packages/cdxcore/cdxcore/subdir.py:4040, in CacheCallable._wrap.<locals>.execute(override_cache_mode, track_cached_files, return_cache_uid, *args, **kwargs)
#    4038     if not k in arguments:
#    4039         args_ = [ f"'{_}'" for _ in arguments ]
# -> 4040         raise ValueError(f"Error while generating '{which}' for '{name}': function expected a parameter '{k}' which is not present "+\
#    4041                          f"in the list of parameters passed to '{name}': {fmt_list(args_)}.")
#    4042     fargs[k] = arguments[k]
#    4043 arguments = fargs
#
# ValueError: Error while generating 'label' for 'f@__main__': function expected a parameter 'z' which is not present in the list of parameters passed to 'f@__main__': 'func_name', 'x' and 'y'.

# %%
from string import Formatter

def expected_args(fmt: str):
    """
    Inspect a format string and report what arguments it expects.
    Returns:
      - auto_positional: count of automatic '{}' fields
      - positional_indices: explicit numeric field indices used (e.g., {0}, {2})
      - keywords: named fields used (e.g., {user}, {price})
    """
    f = Formatter()
    pos = set()
    auto = 0
    kws = set()

    for literal, field, spec, conv in f.parse(fmt):
        if field is None:
            continue
        # Keep only the first identifier before attribute/index access
        head = field.split('.')[0].split('[')[0]
        if head == "":               # '{}' → automatic positional
            auto += 1
        elif head.isdigit():         # '{0}', '{2}' → explicit positional
            pos.add(int(head))
        else:                        # '{name}' → keyword
            kws.add(head)

    return {
        "auto_positional": auto,
        "positional_indices": sorted(pos),
        "keywords": sorted(kws),
    }

expected_args("{_}")
# Out:
# {'auto_positional': 0, 'positional_indices': [], 'keywords': ['_']}

# %%
"{2} {1}".format(x=1,y=2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 "{2} {1}".format(x=1,y=2)
#
# IndexError: Replacement index 2 out of range for positional args tuple

# %%
from collections import OrderedDict

x = OrderedDict(x=1,y=2)
z = OrderedDict(x)

# %%
z |= x
